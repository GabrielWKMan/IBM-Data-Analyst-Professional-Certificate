# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
import matplotlib.pyplot as plt
from PIL import Image # converting images into arrays

# install wordcloud
# !pip3 install wordcloud==1.8.1
# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS

import urllib
# open the file and read it into a variable alice_novel
alice_novel = urllib.request.urlopen('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/alice_novel.txt').read().decode("utf-8")

# save mask to alice_mask
alice_mask = np.array(Image.open(urllib.request.urlopen('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%204/images/alice_mask.png')))

stopwords = set(STOPWORDS)

stopwords.add('said') # add the words said to stopwords

# instantiate a word cloud object
alice_wc = WordCloud(background_color='white', max_words=2000, mask=alice_mask, stopwords=stopwords)

# generate the word cloud
alice_wc.generate(alice_novel)

# display the cloud
fig = plt.figure(figsize=(14, 18))

plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Requirement already satisfied: wordcloud==1.8.1 in c:\users\student236\anaconda3\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\student236\anaconda3\lib\site-packages (from wordcloud==1.8.1) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\student236\anaconda3\lib\site-packages (from wordcloud==1.8.1) (3.5.1)
# Requirement already satisfied: pillow in c:\users\student236\anaconda3\lib\site-packages (from wordcloud==1.8.1) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\student236\anaconda3\lib\site-packages (from matplotlib->wordcloud==1.8.1) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\student236\anaconda3\lib\site-packages (from matplotlib->wordcloud==1.8.1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\student236\anaconda3\lib\site-packages (from matplotlib->wordcloud==1.8.1) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\student236\anaconda3\lib\site-packages (from matplotlib->wordcloud==1.8.1) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\student236\anaconda3\lib\site-packages (from matplotlib->wordcloud==1.8.1) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\student236\anaconda3\lib\site-packages (from matplotlib->wordcloud==1.8.1) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\student236\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud==1.8.1) (1.16.0)
